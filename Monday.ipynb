# %%
import pandas as pd

# %%
df = pd.read_csv("data/Motor_Vehicle_Collisions_-_Crashes.csv")

df
# Out:
# C:\Users\fnafa\AppData\Local\Temp\ipykernel_23736\2248581343.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Motor_Vehicle_Collisions_-_Crashes.csv")
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1        03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2        06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3        09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4        12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# ...             ...        ...        ...      ...        ...        ...
# 2018958  07/03/2023      18:05        NaN      NaN  40.866806 -73.931010
# 2018959  07/22/2023      21:39      BRONX  10457.0  40.844177 -73.902920
# 2018960  07/02/2023      17:55  MANHATTAN  10006.0  40.711033 -74.014540
# ...

# %%
df.shape
# Out:
# (357326, 29)

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN       NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN       NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN       NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN   11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN   11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  233521.000000  327728.000000  327728.000000              357325.000000
# mean    10897.279495      40.407196     -73.335454                   0.419212
# std       523.264426       3.589742       6.513926                   0.766612
# min     10000.000000       0.000000     -74.254845                   0.000000
# 25%     10457.000000      40.666412     -73.961230                   0.000000
# 50%     11208.000000      40.715857     -73.918540                   0.000000
# 75%     11249.000000      40.784325     -73.863890                   1.000000
# max     11697.000000      40.912884       0.000000                  40.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count             357326.000000                  357326.000000
# mean                   0.002278                       0.065755
# std                    0.050191                       0.260085
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357326 entries, 0 to 357325
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH DATE                     357326 non-null  object
#  1   CRASH TIME                     357326 non-null  object
#  2   BOROUGH                        233566 non-null  object
#  3   ZIP CODE                       233521 non-null  float64
#  4   LATITUDE                       327728 non-null  float64
#  5   LONGITUDE                      327728 non-null  float64
#  6   LOCATION                       327728 non-null  object
#  7   ON STREET NAME                 263671 non-null  object
#  8   CROSS STREET NAME              168659 non-null  object
#  9   OFF STREET NAME                93651 non-null   object
#  10  NUMBER OF PERSONS INJURED      357325 non-null  float64
#  11  NUMBER OF PERSONS KILLED       357326 non-null  int64
# ...

# %%
df[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME', 'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']].describe
# Out:
# <bound method NDFrame.describe of          CRASH DATE CRASH TIME    BOROUGH                 LOCATION  \
# 0        09/11/2021       2:39        NaN                      NaN
# 1        03/26/2022      11:45        NaN                      NaN
# 2        06/29/2022       6:55        NaN                      NaN
# 3        09/11/2021       9:35   BROOKLYN    (40.667202, -73.8665)
# 4        12/14/2021       8:13   BROOKLYN  (40.683304, -73.917274)
# ...             ...        ...        ...                      ...
# 2018958  07/03/2023      18:05        NaN   (40.866806, -73.93101)
# 2018959  07/22/2023      21:39      BRONX   (40.844177, -73.90292)
# 2018960  07/02/2023      17:55  MANHATTAN   (40.711033, -74.01454)
# 2018961  07/22/2023      13:15     QUEENS    (40.69158, -73.79319)
# 2018962  07/22/2023       3:00     QUEENS   (40.70024, -73.792854)
#
#                   ON STREET NAME CROSS STREET NAME          OFF STREET NAME  \
# ...

# %%
df[['ZIP CODE', 'LATITUDE', 'LONGITUDE', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED', 'COLLISION_ID']].describe
# Out:
# <bound method NDFrame.describe of         ZIP CODE   LATITUDE  LONGITUDE  NUMBER OF PERSONS INJURED  \
# 0            NaN        NaN        NaN                        2.0
# 1            NaN        NaN        NaN                        1.0
# 2            NaN        NaN        NaN                        0.0
# 3        11208.0  40.667202 -73.866500                        0.0
# 4        11233.0  40.683304 -73.917274                        0.0
# ...          ...        ...        ...                        ...
# 2018958      NaN  40.866806 -73.931010                        0.0
# 2018959  10457.0  40.844177 -73.902920                        1.0
# 2018960  10006.0  40.711033 -74.014540                        0.0
# 2018961  11433.0  40.691580 -73.793190                        1.0
# 2018962  11433.0  40.700240 -73.792854                        0.0
#
#          NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 0                             0.0                              0
# ...

# %%
df['ZIP CODE'].describe()
# Out:
# count     1390658.0
# unique        426.0
# top         11207.0
# freq        19800.0
# Name: ZIP CODE, dtype: float64

# %%
df['CRASH DATE'].describe()
# Out:
# count        2018963
# unique          4066
# top       01/21/2014
# freq            1161
# Name: CRASH DATE, dtype: object
